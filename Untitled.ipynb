# %%
import yfinance as yf
import matplotlib.pyplot as plt

stock=yf.Ticker('AMZN')

# %%
prices=stock.history(start='2018-01-01', interval='1d')[['Open','High','Low','Close']]

# %%
plt.plot(prices['Close'])

# %%
prices
# Out:
#                    Open         High          Low        Close
# Date
# 2018-01-02  1172.000000  1190.000000  1170.510010  1189.010010
# 2018-01-03  1188.300049  1205.489990  1188.300049  1204.199951
# 2018-01-04  1205.000000  1215.869995  1204.660034  1209.589966
# 2018-01-05  1217.510010  1229.140015  1210.000000  1229.140015
# 2018-01-08  1236.000000  1253.079956  1232.030029  1246.869995
# ...                 ...          ...          ...          ...
# 2021-05-03  3484.729980  3486.649902  3372.699951  3386.489990
# 2021-05-04  3356.189941  3367.979980  3272.129883  3311.870117
# 2021-05-05  3338.860107  3354.699951  3264.360107  3270.540039
# 2021-05-06  3270.000000  3314.399902  3247.199951  3306.370117
# 2021-05-07  3319.090088  3330.889893  3289.070068  3291.610107
#
# [843 rows x 4 columns]

# %%
prices_h=stock.history(start='2020-01-01', interval='1h')
prices_h['date']=prices_h.index.map(lambda x: x.date)

# %%
prices_h[['Close', 'date']]
# Out:
#                                  Close        date
# 2020-01-02 09:30:00-05:00  1868.880127  2020-01-02
# 2020-01-02 10:30:00-05:00  1869.180054  2020-01-02
# 2020-01-02 11:30:00-05:00  1874.489502  2020-01-02
# 2020-01-02 12:30:00-05:00  1876.614990  2020-01-02
# 2020-01-02 13:30:00-05:00  1893.500000  2020-01-02
# ...                                ...         ...
# 2021-05-07 11:30:00-04:00  3308.719971  2021-05-07
# 2021-05-07 12:30:00-04:00  3299.060059  2021-05-07
# 2021-05-07 13:30:00-04:00  3302.169922  2021-05-07
# 2021-05-07 14:30:00-04:00  3298.770020  2021-05-07
# 2021-05-07 15:30:00-04:00  3290.689941  2021-05-07
#
# [2373 rows x 2 columns]

# %%
prices_h=prices_h[['Close', 'date']].groupby('date').std()

# %%
prices
# Out:
#                    Open         High          Low        Close
# Date
# 2018-01-02  1172.000000  1190.000000  1170.510010  1189.010010
# 2018-01-03  1188.300049  1205.489990  1188.300049  1204.199951
# 2018-01-04  1205.000000  1215.869995  1204.660034  1209.589966
# 2018-01-05  1217.510010  1229.140015  1210.000000  1229.140015
# 2018-01-08  1236.000000  1253.079956  1232.030029  1246.869995
# ...                 ...          ...          ...          ...
# 2021-05-03  3484.729980  3486.649902  3372.699951  3386.489990
# 2021-05-04  3356.189941  3367.979980  3272.129883  3311.870117
# 2021-05-05  3338.860107  3354.699951  3264.360107  3270.540039
# 2021-05-06  3270.000000  3314.399902  3247.199951  3306.370117
# 2021-05-07  3319.090088  3330.889893  3289.070068  3291.610107
#
# [843 rows x 4 columns]

# %%
prices=prices.merge(prices_h, how='left', left_index=True, right_index=True)

# %%
prices=prices.rename(columns={'Close_y':'volatility', 'Close_x':'Close'})

# %%
prices
# Out:
#                    Open         High          Low        Close  volatility
# Date
# 2018-01-02  1172.000000  1190.000000  1170.510010  1189.010010         NaN
# 2018-01-03  1188.300049  1205.489990  1188.300049  1204.199951         NaN
# 2018-01-04  1205.000000  1215.869995  1204.660034  1209.589966         NaN
# 2018-01-05  1217.510010  1229.140015  1210.000000  1229.140015         NaN
# 2018-01-08  1236.000000  1253.079956  1232.030029  1246.869995         NaN
# ...                 ...          ...          ...          ...         ...
# 2021-05-03  3484.729980  3486.649902  3372.699951  3386.489990   29.556059
# 2021-05-04  3356.189941  3367.979980  3272.129883  3311.870117   18.500544
# 2021-05-05  3338.860107  3354.699951  3264.360107  3270.540039   18.083243
# 2021-05-06  3270.000000  3314.399902  3247.199951  3306.370117   16.985053
# 2021-05-07  3319.090088  3330.889893  3289.070068  3291.610107   11.127798
#
# [843 rows x 5 columns]

# %%
import numpy as np

# %%
prices['returns_month']=((prices['Close']-prices['Close'].shift(25))/prices['Close'].shift(25))/(prices['volatility']*np.sqrt(25))
prices['returns_2month']=(prices['Close']-prices['Close'].shift(2*25))/prices['Close'].shift(2*25)/(prices['volatility']*np.sqrt(2*25))
prices['returns_3month']=(prices['Close']-prices['Close'].shift(3*25))/prices['Close'].shift(3*25)/(prices['volatility']*np.sqrt(3*25))
prices['returns_year']=(prices['Close']-prices['Close'].shift(252))/prices['Close'].shift(252)/(prices['volatility']*np.sqrt(252))

# %%
exp1 = prices['Close'].ewm(span=12, adjust=False).mean()
exp2 = prices['Close'].ewm(span=26, adjust=False).mean()
prices['macd'] = exp1 - exp2

# %%
prices['macd'].plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-220-b786fb1e5fad> in <module>
# ----> 1 prices['macd'].plot()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     match = is_list_like(label_kw) and len(label_kw) == len(y)
#     948                     if label_kw and not match:
# --> 949                         raise ValueError(
#     950                             "label should be list-like and same length as y"
#     951                         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     285         for ax in self.axes:
#     286             self._post_plot_logic_common(ax, self.data)
# --> 287             self._post_plot_logic(ax, self.data)
#     288
#     289     def _args_adjust(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _post_plot_logic(self, ax, data)
#    1270         condition = (
#    1271             not self._use_dynamic_x()
# -> 1272             and (data.index._is_all_dates and self.use_index)
#    1273             and (not self.subplots or (self.subplots and self.sharex))
#    1274         )
#
# AttributeError: 'DatetimeIndex' object has no attribute '_is_all_dates'

# %%
prices['Close'].plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-221-b3b8c11287fd> in <module>
# ----> 1 prices['Close'].plot()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     match = is_list_like(label_kw) and len(label_kw) == len(y)
#     948                     if label_kw and not match:
# --> 949                         raise ValueError(
#     950                             "label should be list-like and same length as y"
#     951                         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     285         for ax in self.axes:
#     286             self._post_plot_logic_common(ax, self.data)
# --> 287             self._post_plot_logic(ax, self.data)
#     288
#     289     def _args_adjust(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _post_plot_logic(self, ax, data)
#    1270         condition = (
#    1271             not self._use_dynamic_x()
# -> 1272             and (data.index._is_all_dates and self.use_index)
#    1273             and (not self.subplots or (self.subplots and self.sharex))
#    1274         )
#
# AttributeError: 'DatetimeIndex' object has no attribute '_is_all_dates'

# %%
import pandas as pd

# %%
def get_rsi_timeseries(prices, n=30):
    # RSI = 100 - (100 / (1 + RS))
    # where RS = (Wilder-smoothed n-period average of gains / Wilder-smoothed n-period average of -losses)
    # Note that losses above should be positive values
    # Wilder-smoothing = ((previous smoothed avg * (n-1)) + current value to average) / n
    # For the very first "previous smoothed avg" (aka the seed value), we start with a straight average.
    # Therefore, our first RSI value will be for the n+2nd period:
    #     0: first delta is nan
    #     1:
    #     ...
    #     n: lookback period for first Wilder smoothing seed value
    #     n+1: first RSI

    # First, calculate the gain or loss from one price to the next. The first value is nan so replace with 0.
    deltas = (prices-prices.shift(1)).fillna(0)

    # Calculate the straight average seed values.
    # The first delta is always zero, so we will use a slice of the first n deltas starting at 1,
    # and filter only deltas > 0 to get gains and deltas < 0 to get losses
    avg_of_gains = deltas[1:n+1][deltas > 0].sum() / n
    avg_of_losses = -deltas[1:n+1][deltas < 0].sum() / n

    # Set up pd.Series container for RSI values
    rsi_series = pd.Series(0.0, deltas.index)

    # Now calculate RSI using the Wilder smoothing method, starting with n+1 delta.
    up = lambda x: x if x > 0 else 0
    down = lambda x: -x if x < 0 else 0
    i = n+1
    for d in deltas[n+1:]:
        avg_of_gains = ((avg_of_gains * (n-1)) + up(d)) / n
        avg_of_losses = ((avg_of_losses * (n-1)) + down(d)) / n
        if avg_of_losses != 0:
            rs = avg_of_gains / avg_of_losses
            rsi_series[i] = 100 - (100 / (1 + rs))
        else:
            rsi_series[i] = 100
        i += 1

    return rsi_series

# %%
prices['rsi']=get_rsi_timeseries(prices['Close'])

# %%
prices.dropna()
# Out:
#                    Open         High          Low        Close  volatility  \
# Date
# 2020-01-02  1875.000000  1898.010010  1864.150024  1898.010010   12.458887
# 2020-01-03  1864.500000  1886.199951  1864.500000  1874.969971    2.710803
# 2020-01-06  1860.000000  1903.689941  1860.000000  1902.880005    3.555184
# 2020-01-07  1904.500000  1913.890015  1892.040039  1906.859985    4.128775
# 2020-01-08  1898.040039  1911.000000  1886.439941  1891.969971    4.659045
# ...                 ...          ...          ...          ...         ...
# 2021-05-03  3484.729980  3486.649902  3372.699951  3386.489990   29.556059
# 2021-05-04  3356.189941  3367.979980  3272.129883  3311.870117   18.500544
# 2021-05-05  3338.860107  3354.699951  3264.360107  3270.540039   18.083243
# 2021-05-06  3270.000000  3314.399902  3247.199951  3306.370117   16.985053
# 2021-05-07  3319.090088  3330.889893  3289.070068  3291.610107   11.127798
#
#             returns_month  returns_2month  returns_3month  returns_year  \
# Date
# 2020-01-02       0.001124        0.000714        0.000462      0.001179
# 2020-01-03       0.003204        0.003228        0.001225      0.005804
# 2020-01-06       0.002610        0.003176        0.001527      0.003683
# 2020-01-07       0.002853        0.002425        0.001311      0.002597
# 2020-01-08       0.002659        0.002251        0.001351      0.001921
# ...                   ...             ...             ...           ...
# 2021-05-03       0.000742        0.000201        0.000272      0.001026
# 2021-05-04       0.000830        0.000315        0.000368      0.001464
# 2021-05-05       0.000779        0.000186        0.000342      0.001432
# 2021-05-06       0.000808        0.000387        0.000404      0.001507
# 2021-05-07       0.000743        0.000975        0.000090      0.002209
#
#                  macd        rsi
# Date
# 2020-01-02  26.130706  62.204589
# 2020-01-03  27.845007  59.128001
# 2020-01-06  31.097240  61.513379
# 2020-01-07  33.608392  61.841899
# 2020-01-08  34.005011  59.864215
# ...               ...        ...
# 2021-05-03  65.333021  55.685143
# 2021-05-04  53.910549  52.220700
# 2021-05-05  41.049966  50.423237
# 2021-05-06  33.364445  51.907793
# 2021-05-07  25.785367  51.253750
#
# [340 rows x 11 columns]

# %%
def preprocess(stock, start):
    stck=yf.Ticker(stock)
    data=stck.history(start=start, interval='1d')[['Open','High','Low','Close']]
    
    #prices_h=stck.history(start='2020-01-01', interval='1h')
    #prices_h['date']=prices_h.index.map(lambda x: x.date)
    #prices_h=prices_h[['Close', 'date']].groupby('date').std()
    
    #data=data.merge(prices_h, how='left', left_index=True, right_index=True)
    #data=data.rename(columns={'Close_y':'volatility', 'Close_x':'Close'})
    
    #data['returns_month']=((data['Close']-data['Close'].shift(25))/data['Close'].shift(25))/(data['volatility']*np.sqrt(25))
    #data['returns_2month']=(data['Close']-data['Close'].shift(2*25))/data['Close'].shift(2*25)/(data['volatility']*np.sqrt(2*25))
    #data['returns_3month']=(data['Close']-data['Close'].shift(3*25))/data['Close'].shift(3*25)/(data['volatility']*np.sqrt(3*25))
    #data['returns_year']=(data['Close']-data['Close'].shift(252))/data['Close'].shift(252)/(data['volatility']*np.sqrt(252))
    
    data['returns_month']=((data['Close']-data['Close'].shift(25))/data['Close'].shift(25))
    data['returns_2month']=(data['Close']-data['Close'].shift(2*25))/data['Close'].shift(2*25)
    data['returns_3month']=(data['Close']-data['Close'].shift(3*25))/data['Close'].shift(3*25)
    data['returns_year']=(data['Close']-data['Close'].shift(252))/data['Close'].shift(252)
   
    exp1 = data['Close'].ewm(span=12, adjust=False).mean()
    exp2 = data['Close'].ewm(span=26, adjust=False).mean()
    data['macd'] = exp1 - exp2
    
    data['rsi']=get_rsi_timeseries(data['Close'])
    
    data=data.dropna()
    
    return data

# %%
amzn=preprocess('amzn', start='2015-01-01')

# %%
amzn.to_csv('amzn.csv')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-200-b0df7e848fbe> in <module>
# ----> 1 amzn.to_csv('amzn.csv')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3143             tabular output.
#    3144         DataFrame.to_html : Render a DataFrame as an HTML table.
# -> 3145
#    3146         Examples
#    3147         --------
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in <module>
#      10
#      11 from pandas._libs import writers as libwriters
# ---> 12 from pandas._typing import (
#      13     CompressionOptions,
#      14     FilePathOrBuffer,
#
# ImportError: cannot import name 'CompressionOptions' from 'pandas._typing' (/Users/mouniaelbaz/opt/anaconda3/lib/python3.8/site-packages/pandas/_typing.py)

# %%
ls
# Out:
# Q-Learning-for-Trading/ Untitled.ipynb

# %%
cd Q-Learning-for-Trading
# Out:
# /Users/mouniaelbaz/Desktop/CS/Reinforcement Learning/Q-Learning-for-Trading

# %%
ls
# Out:
# README.md         envs.py           portfolio_val/    venv/
# __pycache__/      fit.py            preprocess.py     weights/
# agent.py          model.py          requirements.txt
# agent_torch.py    model_torch.py    run.py
# data/             portfolio_hist/   utils.py

# %%
cd portfolio_hist
# Out:
# /Users/mouniaelbaz/Desktop/CS/Reinforcement Learning/Q-Learning-for-Trading/portfolio_hist

# %%
cd ..
# Out:
# /Users/mouniaelbaz/Desktop/CS/Reinforcement Learning/Q-Learning-for-Trading

# %%
a=pd.read_pickle('portfolio_hist/202105162317-test-DuelingDQN.p')

# %%
a
# Out:
# [20000.0,
#  20000.0,
#  20000.0,
#  20000.0,
#  20740.0,
#  20740.0,
#  20740.0,
#  20740.0,
#  20740.0,
#  20740.0,
#  20000.0,
#  20740.0,
#  20740.0,
#  20740.0,
#  20740.0,
#  20740.0,
#  20740.0,
#  20740.0,
#  21141.0,
#  20930.0,
#  20930.0,
#  21097.0,
#  21345.0,
#  21263.0,
#  21349.0,
#  21349.0,
#  21349.0,
#  21349.0,
#  21349.0,
#  21603.0,
#  21857.0,
#  21857.0,
#  21487.0,
#  22227.0,
#  22227.0,
#  22227.0,
#  22001.0,
#  21775.0,
#  21425.0,
#  21775.0,
#  22473.0,
#  22125.0,
#  22125.0,
#  21773.0,
#  21773.0,
#  21597.0,
#  21597.0,
#  21597.0,
#  21597.0,
#  21597.0,
#  20923.0,
#  21260.0,
#  21032.0,
#  21270.0,
#  21501.0,
#  21501.0,
#  21263.0,
#  21263.0,
#  21263.0,
#  21263.0,
#  21263.0,
#  21263.0,
#  21811.0,
#  21674.0,
#  21674.0,
#  21674.0,
#  22363.0,
#  22363.0,
#  22363.0,
#  22126.0,
#  22126.0,
#  23011.0,
#  22126.0,
#  23011.0,
#  22126.0,
#  22126.0,
#  23011.0,
#  22434.0,
#  22722.0,
#  23410.0,
#  25210.0,
#  24834.0,
#  24834.0,
#  24458.0,
#  24082.0,
#  24082.0,
#  24858.0,
#  25246.0,
#  25246.0,
#  25246.0,
#  25246.0,
#  25246.0,
#  25246.0,
#  25246.0,
#  25246.0,
#  24956.0,
#  24956.0,
#  24956.0,
#  24956.0]

# %%
plt.plot(a)

# %%
pip install Historic-Crypto
# Out:
# Collecting Historic-Crypto
#   Downloading Historic_Crypto-0.1.4-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: pandas in /Users/mouniaelbaz/opt/anaconda3/lib/python3.8/site-packages (from Historic-Crypto) (1.2.4)
# Requirement already satisfied: tqdm in /Users/mouniaelbaz/opt/anaconda3/lib/python3.8/site-packages (from Historic-Crypto) (4.50.2)
# Requirement already satisfied: requests in /Users/mouniaelbaz/opt/anaconda3/lib/python3.8/site-packages (from Historic-Crypto) (2.24.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/mouniaelbaz/opt/anaconda3/lib/python3.8/site-packages (from pandas->Historic-Crypto) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/mouniaelbaz/opt/anaconda3/lib/python3.8/site-packages (from pandas->Historic-Crypto) (2020.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/mouniaelbaz/opt/anaconda3/lib/python3.8/site-packages (from pandas->Historic-Crypto) (1.20.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/mouniaelbaz/opt/anaconda3/lib/python3.8/site-packages (from requests->Historic-Crypto) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mouniaelbaz/opt/anaconda3/lib/python3.8/site-packages (from requests->Historic-Crypto) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /Users/mouniaelbaz/opt/anaconda3/lib/python3.8/site-packages (from requests->Historic-Crypto) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/mouniaelbaz/opt/anaconda3/lib/python3.8/site-packages (from requests->Historic-Crypto) (3.0.4)
# Requirement already satisfied: six>=1.5 in /Users/mouniaelbaz/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->Historic-Crypto) (1.15.0)
# Installing collected packages: Historic-Crypto
# Successfully installed Historic-Crypto-0.1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from Historic_Crypto import HistoricalData
from Historic_Crypto import Cryptocurrencies
from Historic_Crypto import LiveCryptoData

# %%
from Historic_Crypto import HistoricalData

new = HistoricalData('ETH-USD',300,'2020-06-01-00-00').retrieve_data()
# Out:
# Checking input parameters are in the correct format...
# Formatting Dates...
# Checking if ticker supplied is available on the CoinBase Pro API...
# Connected to the CoinBase Pro API...
# Ticker 'ETH-USD' found at the CoinBase Pro API, continuing to extraction...
# Data for chunk 0 of 335 extracted
# Data for chunk 1 of 335 extracted
# Data for chunk 2 of 335 extracted
# Data for chunk 3 of 335 extracted
# Data for chunk 4 of 335 extracted
# Data for chunk 5 of 335 extracted
# Data for chunk 6 of 335 extracted
# Data for chunk 7 of 335 extracted
# Data for chunk 8 of 335 extracted
# Data for chunk 9 of 335 extracted
# Data for chunk 10 of 335 extracted
# Data for chunk 11 of 335 extracted
# Data for chunk 12 of 335 extracted
# Data for chunk 13 of 335 extracted
# Data for chunk 14 of 335 extracted
# Data for chunk 15 of 335 extracted
# Data for chunk 16 of 335 extracted
# Data for chunk 17 of 335 extracted
# Data for chunk 18 of 335 extracted
# Data for chunk 19 of 335 extracted
# Data for chunk 20 of 335 extracted
# Data for chunk 21 of 335 extracted
# Data for chunk 22 of 335 extracted
# Data for chunk 23 of 335 extracted
# Data for chunk 24 of 335 extracted
# Data for chunk 25 of 335 extracted
# Data for chunk 26 of 335 extracted
# Data for chunk 27 of 335 extracted
# Data for chunk 28 of 335 extracted
# Data for chunk 29 of 335 extracted
# Data for chunk 30 of 335 extracted
# Data for chunk 31 of 335 extracted
# Data for chunk 32 of 335 extracted
# Data for chunk 33 of 335 extracted
# Data for chunk 34 of 335 extracted
# Data for chunk 35 of 335 extracted
# Data for chunk 36 of 335 extracted
# Data for chunk 37 of 335 extracted
# Data for chunk 38 of 335 extracted
# Data for chunk 39 of 335 extracted
# Data for chunk 40 of 335 extracted
# Data for chunk 41 of 335 extracted
# Data for chunk 42 of 335 extracted
# Data for chunk 43 of 335 extracted
# Data for chunk 44 of 335 extracted
# Data for chunk 45 of 335 extracted
# Data for chunk 46 of 335 extracted
# Data for chunk 47 of 335 extracted
# Data for chunk 48 of 335 extracted
# Data for chunk 49 of 335 extracted
# Data for chunk 50 of 335 extracted
# Data for chunk 51 of 335 extracted
# Data for chunk 52 of 335 extracted
# Data for chunk 53 of 335 extracted
# Data for chunk 54 of 335 extracted
# Data for chunk 55 of 335 extracted
# Data for chunk 56 of 335 extracted
# Data for chunk 57 of 335 extracted
# Data for chunk 58 of 335 extracted
# Data for chunk 59 of 335 extracted
# Data for chunk 60 of 335 extracted
# Data for chunk 61 of 335 extracted
# Data for chunk 62 of 335 extracted
# Data for chunk 63 of 335 extracted
# Data for chunk 64 of 335 extracted
# Data for chunk 65 of 335 extracted
# Data for chunk 66 of 335 extracted
# Data for chunk 67 of 335 extracted
# Data for chunk 68 of 335 extracted
# Data for chunk 69 of 335 extracted
# Data for chunk 70 of 335 extracted
# Data for chunk 71 of 335 extracted
# Data for chunk 72 of 335 extracted
# Data for chunk 73 of 335 extracted
# Data for chunk 74 of 335 extracted
# Data for chunk 75 of 335 extracted
# Data for chunk 76 of 335 extracted
# Data for chunk 77 of 335 extracted
# Data for chunk 78 of 335 extracted
# Data for chunk 79 of 335 extracted
# Data for chunk 80 of 335 extracted
# Data for chunk 81 of 335 extracted
# Data for chunk 82 of 335 extracted
# Data for chunk 83 of 335 extracted
# Data for chunk 84 of 335 extracted
# Data for chunk 85 of 335 extracted
# Data for chunk 86 of 335 extracted
# Data for chunk 87 of 335 extracted
# Data for chunk 88 of 335 extracted
# Data for chunk 89 of 335 extracted
# Data for chunk 90 of 335 extracted
# Data for chunk 91 of 335 extracted
# Data for chunk 92 of 335 extracted
# Data for chunk 93 of 335 extracted
# Data for chunk 94 of 335 extracted
# Data for chunk 95 of 335 extracted
# Data for chunk 96 of 335 extracted
# Data for chunk 97 of 335 extracted
# Data for chunk 98 of 335 extracted
# Data for chunk 99 of 335 extracted
# Data for chunk 100 of 335 extracted
# Data for chunk 101 of 335 extracted
# Data for chunk 102 of 335 extracted
# Data for chunk 103 of 335 extracted
# Data for chunk 104 of 335 extracted
# Data for chunk 105 of 335 extracted
# Data for chunk 106 of 335 extracted
# Data for chunk 107 of 335 extracted
# Data for chunk 108 of 335 extracted
# Data for chunk 109 of 335 extracted
# Data for chunk 110 of 335 extracted
# Data for chunk 111 of 335 extracted
# Data for chunk 112 of 335 extracted
# Data for chunk 113 of 335 extracted
# Data for chunk 114 of 335 extracted
# Data for chunk 115 of 335 extracted
# Data for chunk 116 of 335 extracted
# Data for chunk 117 of 335 extracted
# Data for chunk 118 of 335 extracted
# Data for chunk 119 of 335 extracted
# Data for chunk 120 of 335 extracted
# Data for chunk 121 of 335 extracted
# Data for chunk 122 of 335 extracted
# Data for chunk 123 of 335 extracted
# Data for chunk 124 of 335 extracted
# Data for chunk 125 of 335 extracted
# Data for chunk 126 of 335 extracted
# Data for chunk 127 of 335 extracted
# Data for chunk 128 of 335 extracted
# Data for chunk 129 of 335 extracted
# Data for chunk 130 of 335 extracted
# Data for chunk 131 of 335 extracted
# Data for chunk 132 of 335 extracted
# Data for chunk 133 of 335 extracted
# Data for chunk 134 of 335 extracted
# Data for chunk 135 of 335 extracted
# Data for chunk 136 of 335 extracted
# Data for chunk 137 of 335 extracted
# Data for chunk 138 of 335 extracted
# Data for chunk 139 of 335 extracted
# Data for chunk 140 of 335 extracted
# Data for chunk 141 of 335 extracted
# Data for chunk 142 of 335 extracted
# Data for chunk 143 of 335 extracted
# Data for chunk 144 of 335 extracted
# Data for chunk 145 of 335 extracted
# Data for chunk 146 of 335 extracted
# Data for chunk 147 of 335 extracted
# Data for chunk 148 of 335 extracted
# Data for chunk 149 of 335 extracted
# Data for chunk 150 of 335 extracted
# Data for chunk 151 of 335 extracted
# Data for chunk 152 of 335 extracted
# Data for chunk 153 of 335 extracted
# Data for chunk 154 of 335 extracted
# Data for chunk 155 of 335 extracted
# Data for chunk 156 of 335 extracted
# Data for chunk 157 of 335 extracted
# Data for chunk 158 of 335 extracted
# Data for chunk 159 of 335 extracted
# Data for chunk 160 of 335 extracted
# Data for chunk 161 of 335 extracted
# Data for chunk 162 of 335 extracted
# Data for chunk 163 of 335 extracted
# Data for chunk 164 of 335 extracted
# Data for chunk 165 of 335 extracted
# Data for chunk 166 of 335 extracted
# Data for chunk 167 of 335 extracted
# Data for chunk 168 of 335 extracted
# Data for chunk 169 of 335 extracted
# Data for chunk 170 of 335 extracted
# Data for chunk 171 of 335 extracted
# Data for chunk 172 of 335 extracted
# Data for chunk 173 of 335 extracted
# Data for chunk 174 of 335 extracted
# Data for chunk 175 of 335 extracted
# Data for chunk 176 of 335 extracted
# Data for chunk 177 of 335 extracted
# Data for chunk 178 of 335 extracted
# Data for chunk 179 of 335 extracted
# Data for chunk 180 of 335 extracted
# Data for chunk 181 of 335 extracted
# Data for chunk 182 of 335 extracted
# Data for chunk 183 of 335 extracted
# Data for chunk 184 of 335 extracted
# Data for chunk 185 of 335 extracted
# Data for chunk 186 of 335 extracted
# Data for chunk 187 of 335 extracted
# Data for chunk 188 of 335 extracted
# Data for chunk 189 of 335 extracted
# Data for chunk 190 of 335 extracted
# Data for chunk 191 of 335 extracted
# Data for chunk 192 of 335 extracted
# Data for chunk 193 of 335 extracted
# Data for chunk 194 of 335 extracted
# Data for chunk 195 of 335 extracted
# Data for chunk 196 of 335 extracted
# Data for chunk 197 of 335 extracted
# Data for chunk 198 of 335 extracted
# Data for chunk 199 of 335 extracted
# Data for chunk 200 of 335 extracted
# Data for chunk 201 of 335 extracted
# Data for chunk 202 of 335 extracted
# Data for chunk 203 of 335 extracted
# Data for chunk 204 of 335 extracted
# Data for chunk 205 of 335 extracted
# Data for chunk 206 of 335 extracted
# Data for chunk 207 of 335 extracted
# Data for chunk 208 of 335 extracted
# Data for chunk 209 of 335 extracted
# Data for chunk 210 of 335 extracted
# Data for chunk 211 of 335 extracted
# Data for chunk 212 of 335 extracted
# Data for chunk 213 of 335 extracted
# Data for chunk 214 of 335 extracted
# Data for chunk 215 of 335 extracted
# Data for chunk 216 of 335 extracted
# Data for chunk 217 of 335 extracted
# Data for chunk 218 of 335 extracted
# Data for chunk 219 of 335 extracted
# Data for chunk 220 of 335 extracted
# Data for chunk 221 of 335 extracted
# Data for chunk 222 of 335 extracted
# Data for chunk 223 of 335 extracted
# Data for chunk 224 of 335 extracted
# Data for chunk 225 of 335 extracted
# Data for chunk 226 of 335 extracted
# Data for chunk 227 of 335 extracted
# Data for chunk 228 of 335 extracted
# Data for chunk 229 of 335 extracted
# Data for chunk 230 of 335 extracted
# Data for chunk 231 of 335 extracted
# Data for chunk 232 of 335 extracted
# Data for chunk 233 of 335 extracted
# Data for chunk 234 of 335 extracted
# Data for chunk 235 of 335 extracted
# Data for chunk 236 of 335 extracted
# Data for chunk 237 of 335 extracted
# Data for chunk 238 of 335 extracted
# Data for chunk 239 of 335 extracted
# Data for chunk 240 of 335 extracted
# Data for chunk 241 of 335 extracted
# Data for chunk 242 of 335 extracted
# Data for chunk 243 of 335 extracted
# Data for chunk 244 of 335 extracted
# Data for chunk 245 of 335 extracted
# Data for chunk 246 of 335 extracted
# Data for chunk 247 of 335 extracted
# Data for chunk 248 of 335 extracted
# Data for chunk 249 of 335 extracted
# Data for chunk 250 of 335 extracted
# Data for chunk 251 of 335 extracted
# Data for chunk 252 of 335 extracted
# Data for chunk 253 of 335 extracted
# Data for chunk 254 of 335 extracted
# Data for chunk 255 of 335 extracted
# Data for chunk 256 of 335 extracted
# Data for chunk 257 of 335 extracted
# Data for chunk 258 of 335 extracted
# Data for chunk 259 of 335 extracted
# Data for chunk 260 of 335 extracted
# Data for chunk 261 of 335 extracted
# Data for chunk 262 of 335 extracted
# Data for chunk 263 of 335 extracted
# Data for chunk 264 of 335 extracted
# Data for chunk 265 of 335 extracted
# Data for chunk 266 of 335 extracted
# Data for chunk 267 of 335 extracted
# Data for chunk 268 of 335 extracted
# Data for chunk 269 of 335 extracted
# Data for chunk 270 of 335 extracted
# Data for chunk 271 of 335 extracted
# Data for chunk 272 of 335 extracted
# Data for chunk 273 of 335 extracted
# Data for chunk 274 of 335 extracted
# Data for chunk 275 of 335 extracted
# Data for chunk 276 of 335 extracted
# Data for chunk 277 of 335 extracted
# Data for chunk 278 of 335 extracted
# Data for chunk 279 of 335 extracted
# Data for chunk 280 of 335 extracted
# Data for chunk 281 of 335 extracted
# Data for chunk 282 of 335 extracted
# Data for chunk 283 of 335 extracted
# Data for chunk 284 of 335 extracted
# Data for chunk 285 of 335 extracted
# Data for chunk 286 of 335 extracted
# Data for chunk 287 of 335 extracted
# Data for chunk 288 of 335 extracted
# Data for chunk 289 of 335 extracted
# Data for chunk 290 of 335 extracted
# Data for chunk 291 of 335 extracted
# Data for chunk 292 of 335 extracted
# Data for chunk 293 of 335 extracted
# Data for chunk 294 of 335 extracted
# Data for chunk 295 of 335 extracted
# Data for chunk 296 of 335 extracted
# Data for chunk 297 of 335 extracted
# Data for chunk 298 of 335 extracted
# Data for chunk 299 of 335 extracted
# Data for chunk 300 of 335 extracted
# Data for chunk 301 of 335 extracted
# Data for chunk 302 of 335 extracted
# Data for chunk 303 of 335 extracted
# Data for chunk 304 of 335 extracted
# Data for chunk 305 of 335 extracted
# Data for chunk 306 of 335 extracted
# Data for chunk 307 of 335 extracted
# Data for chunk 308 of 335 extracted
# Data for chunk 309 of 335 extracted
# Data for chunk 310 of 335 extracted
# Data for chunk 311 of 335 extracted
# Data for chunk 312 of 335 extracted
# Data for chunk 313 of 335 extracted
# Data for chunk 314 of 335 extracted
# Data for chunk 315 of 335 extracted
# Data for chunk 316 of 335 extracted
# Data for chunk 317 of 335 extracted
# Data for chunk 318 of 335 extracted
# Data for chunk 319 of 335 extracted
# Data for chunk 320 of 335 extracted
# Data for chunk 321 of 335 extracted
# Data for chunk 322 of 335 extracted
# Data for chunk 323 of 335 extracted
# Data for chunk 324 of 335 extracted
# Data for chunk 325 of 335 extracted
# Data for chunk 326 of 335 extracted
# Data for chunk 327 of 335 extracted
# Data for chunk 328 of 335 extracted
# Data for chunk 329 of 335 extracted
# Data for chunk 330 of 335 extracted
# Data for chunk 331 of 335 extracted
# Data for chunk 332 of 335 extracted
# Data for chunk 333 of 335 extracted
# Data for chunk 334 of 335 extracted
# Data for chunk 335 of 335 extracted

# %%
import pandas_datareader as pdr
import datetime
btc_data = pdr.get_data_yahoo(['BTC-USD'], 
                          start=datetime.datetime(2018, 1, 1), 
                          end=datetime.datetime(2020, 12, 2))['Close']

# %%
btc_data
# Out:
# Symbols          BTC-USD
# Date
# 2018-01-01  13657.200195
# 2018-01-02  14982.099609
# 2018-01-03  15201.000000
# 2018-01-04  15599.200195
# 2018-01-05  17429.500000
# ...                  ...
# 2020-11-29  18177.484375
# 2020-11-30  19625.835938
# 2020-12-01  18802.998047
# 2020-12-02  19201.091797
# 2020-12-03  19445.398438
#
# [1064 rows x 1 columns]
